# %%
import re

import gspread
from oauth2client.service_account import ServiceAccountCredentials
#from pprint import pprintm
from colorama import Fore, Back, Style
scope = ["https://spreadsheets.google.com/feeds",'https://www.googleapis.com/auth/spreadsheets',"https://www.googleapis.com/auth/drive.file","https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name("cred.json", scope)
client = gspread.authorize(creds)
sheet = client.open("Math Work log SECTION 2").sheet1
data = sheet.get_all_records()  # Get a list of all records
ncol = sheet.col_values(1)  # Get a specific column
#print(ncol)
names =ncol[2:]
start = input("Cell num?" )
n = int(start)-3
cutnames = names[n:]
#days = [2,10,18,26,34,42,50]
for name in cutnames:
    r = names.index(name) + 3
    full = input(Fore.WHITE + "Enter data for: " + Fore.GREEN + name)

    mo = re.findall('(m.*?)[twhfsuz]', full)
    tu = re.findall('(t.*?)[whfsuz]', full)
    we = re.findall('(w.*?)[hfsuz]', full)
    th = re.findall('(h.*?)[fsuz]', full)
    fr = re.findall('(f.*?)[suz]', full)
    sa = re.findall('(s.*?)[uz]', full)
    su = re.findall('(u.*?)[z]', full)
    if mo:
        day = 2
        for x in mo:
            m = str(x)
            dot = re.findall('(\d\.\d\d)', m)
            if dot:
                if len(dot) == 2:
                    dot181 = re.findall('m(\d\.\d\d)', m)
                    m181h = float(dot181[0])
                    sheet.update_cell(r, day, m181h)
                    dot191 = re.findall('m\d\.\d\d(\d\.\d\d)', m)
                    m191h = float(dot191[0])
                    d191 = day+1
                    sheet.update_cell(r, d191, m191h)
                    if len(m) > 9:
                        T = m[9:]
                        for x in T:
                            tN = int(x) + 1
                            dayt = day + tN
                            sheet.update_cell(r, dayt, "YES")
                else:
                    dot181 = re.findall('m(\d\.\d\d)', m)
                    if len(dot181) == 0:
                        dot181 = re.findall('m(\d)', m)
                        m181h = float(dot181[0])
                        sheet.update_cell(r, day, m181h)
                        dot191 = re.findall('m\d(\d\.\d\d)', m)
                        m191h = float(dot191[0])
                        d191 = day + 1
                        sheet.update_cell(r, d191, m191h)
                        if len(m) > 6:
                            T = m[6:]
                            for x in T:
                                tN = int(x) + 1
                                dayt = day + tN
                                sheet.update_cell(r, dayt, "YES")
                    else:
                        m181h = float(dot181[0])
                        sheet.update_cell(r, day, m181h)
                        dot191 = re.findall('m\d\.\d\d(\d)', m)
                        m191h = float(dot191[0])
                        d191 = day + 1
                        sheet.update_cell(r, d191, m191h)
                        if len(m) > 6:
                            T = m[6:]
                            for x in T:
                                tN = int(x) + 1
                                dayt = day + tN
                                sheet.update_cell(r, dayt, "YES")
            else:
                dlist = list()
                for x in m:
                    dlist.append(x)
                m181h = int(dlist[1])
                sheet.update_cell(r, day, m181h)
                m191h = int(dlist[2])
                d191 = day + 1
                sheet.update_cell(r, d191, m191h)
                if len(m) > 3:
                    T = m[3:]
                    for x in T:
                        tN = int(x) + 1
                        dayt = day + tN
                        sheet.update_cell(r, dayt, "YES")
    ####################################################################
    if tu:
        day = 10
        for x in tu:
            t = str(x)
            dot = re.findall('(\d\.\d\d)', t)
            if dot:
                if len(dot) == 2:
                    dot181 = re.findall('t(\d\.\d\d)', t)
                    m181h = float(dot181[0])
                    sheet.update_cell(r, day, m181h)
                    dot191 = re.findall('t\d\.\d\d(\d\.\d\d)', t)
                    m191h = float(dot191[0])
                    d191 = day+1
                    sheet.update_cell(r, d191, m191h)
                    if len(t) > 9:
                        T = t[9:]
                        for x in T:
                            tN = int(x) + 1
                            dayt = day + tN
                            sheet.update_cell(r, dayt, "YES")
                else:
                    dot181 = re.findall('t(\d\.\d\d)', t)
                    if len(dot181) == 0:
                        dot181 = re.findall('t(\d)', t)
                        m181h = float(dot181[0])
                        sheet.update_cell(r, day, m181h)
                        dot191 = re.findall('t\d(\d\.\d\d)', t)
                        m191h = float(dot191[0])
                        d191 = day + 1
                        sheet.update_cell(r, d191, m191h)
                        if len(t) > 6:
                            T = t[6:]
                            for x in T:
                                tN = int(x) + 1
                                dayt = day + tN
                                sheet.update_cell(r, dayt, "YES")
                    else:
                        m181h = float(dot181[0])
                        sheet.update_cell(r, day, m181h)
                        dot191 = re.findall('t\d\.\d\d(\d)', t)
                        m191h = float(dot191[0])
                        d191 = day + 1
                        sheet.update_cell(r, d191, m191h)
                        if len(t) > 6:
                            T = t[6:]
                            for x in T:
                                tN = int(x) + 1
                                dayt = day + tN
                                sheet.update_cell(r, dayt, "YES")
            else:
                dlist = list()
                for x in t:
                    dlist.append(x)
                m181h = int(dlist[1])
                sheet.update_cell(r, day, m181h)
                m191h = int(dlist[2])
                d191 = day + 1
                sheet.update_cell(r, d191, m191h)
                if len(t) > 3:
                    T = t[3:]
                    for x in T:
                        tN = int(x) + 1
                        dayt = day + tN
                        sheet.update_cell(r, dayt, "YES")
###########################################################################################
    if we:##############
        day = 18############
        for x in we:###############
            w = str(x)#####################
            dot = re.findall('(\d\.\d\d)', w)################
            if dot:
                if len(dot) == 2:
                    dot181 = re.findall('w(\d\.\d\d)', w)###########################
                    m181h = float(dot181[0])
                    sheet.update_cell(r, day, m181h)
                    dot191 = re.findall('w\d\.\d\d(\d\.\d\d)', w)####################
                    m191h = float(dot191[0])
                    d191 = day+1
                    sheet.update_cell(r, d191, m191h)
                    if len(w) > 9:########   #######
                        T = w[9:]
                        for x in T:
                            tN = int(x) + 1
                            dayt = day + tN
                            sheet.update_cell(r, dayt, "YES")
                else:
                    dot181 = re.findall('w(\d\.\d\d)', w)#####   #####
                    if len(dot181) == 0:
                        dot181 = re.findall('w(\d)', w)#######   #######
                        m181h = float(dot181[0])
                        sheet.update_cell(r, day, m181h)
                        dot191 = re.findall('w\d(\d\.\d\d)', w)#######  ########
                        m191h = float(dot191[0])
                        d191 = day + 1
                        sheet.update_cell(r, d191, m191h)
                        if len(w) > 6:#################
                            T = w[6:]##################
                            for x in T:
                                tN = int(x) + 1
                                dayt = day + tN
                                sheet.update_cell(r, dayt, "YES")
                    else:
                        m181h = float(dot181[0])
                        sheet.update_cell(r, day, m181h)
                        dot191 = re.findall('w\d\.\d\d(\d)', w)#########    ##########
                        m191h = float(dot191[0])
                        d191 = day + 1
                        sheet.update_cell(r, d191, m191h)
                        if len(w) > 6:#######################
                            T = w[6:]########################
                            for x in T:
                                tN = int(x) + 1
                                dayt = day + tN
                                sheet.update_cell(r, dayt, "YES")
            else:
                dlist = list()
                for x in w:##########################
                    dlist.append(x)
                m181h = int(dlist[1])
                sheet.update_cell(r, day, m181h)
                m191h = int(dlist[2])
                d191 = day + 1
                sheet.update_cell(r, d191, m191h)
                if len(w) > 3:################
                    T = w[3:]##############
                    for x in T:
                        tN = int(x) + 1
                        dayt = day + tN
                        sheet.update_cell(r, dayt, "YES")
###########################################################################################
    if th:##############
        day = 26############
        for x in th:###############
            h = str(x)#####################
            dot = re.findall('(\d\.\d\d)', h)################
            if dot:
                if len(dot) == 2:
                    dot181 = re.findall('h(\d\.\d\d)', h)#############     ##############
                    m181h = float(dot181[0])
                    sheet.update_cell(r, day, m181h)
                    dot191 = re.findall('h\d\.\d\d(\d\.\d\d)', h)#########   ###########
                    m191h = float(dot191[0])
                    d191 = day+1
                    sheet.update_cell(r, d191, m191h)
                    if len(h) > 9:###############
                        T = h[9:] ##########
                        for x in T:
                            tN = int(x) + 1
                            dayt = day + tN
                            sheet.update_cell(r, dayt, "YES")
                else:
                    dot181 = re.findall('h(\d\.\d\d)', h)#####   #####
                    if len(dot181) == 0:
                        dot181 = re.findall('h(\d)', h)#######   #######
                        m181h = float(dot181[0])
                        sheet.update_cell(r, day, m181h)
                        dot191 = re.findall('h\d(\d\.\d\d)', h)#######  ########
                        m191h = float(dot191[0])
                        d191 = day + 1
                        sheet.update_cell(r, d191, m191h)
                        if len(h) > 6:#################
                            T = h[6:]##################
                            for x in T:
                                tN = int(x) + 1
                                dayt = day + tN
                                sheet.update_cell(r, dayt, "YES")
                    else:
                        m181h = float(dot181[0])
                        sheet.update_cell(r, day, m181h)
                        dot191 = re.findall('h\d\.\d\d(\d)', h)#########    ##########
                        m191h = float(dot191[0])
                        d191 = day + 1
                        sheet.update_cell(r, d191, m191h)
                        if len(h) > 6:#######################
                            T = h[6:]########################
                            for x in T:
                                tN = int(x) + 1
                                dayt = day + tN
                                sheet.update_cell(r, dayt, "YES")
            else:
                dlist = list()
                for x in h:##########################
                    dlist.append(x)
                m181h = int(dlist[1])
                sheet.update_cell(r, day, m181h)
                m191h = int(dlist[2])
                d191 = day + 1
                sheet.update_cell(r, d191, m191h)
                if len(h) > 3:################
                    T = h[3:]##############
                    for x in T:
                        tN = int(x) + 1
                        dayt = day + tN
                        sheet.update_cell(r, dayt, "YES")
###########################################################################################
    if fr:##############
        day = 34############
        for x in fr:###############
            f = str(x)#####################
            dot = re.findall('(\d\.\d\d)', f)################
            if dot:
                if len(dot) == 2:
                    dot181 = re.findall('f(\d\.\d\d)', f)#############     ##############
                    m181h = float(dot181[0])
                    sheet.update_cell(r, day, m181h)
                    dot191 = re.findall('f\d\.\d\d(\d\.\d\d)', f)#########   ###########
                    m191h = float(dot191[0])
                    d191 = day+1
                    sheet.update_cell(r, d191, m191h)
                    if len(f) > 9:###############
                        T = f[9:] ##########
                        for x in T:
                            tN = int(x) + 1
                            dayt = day + tN
                            sheet.update_cell(r, dayt, "YES")
                else:
                    dot181 = re.findall('f(\d\.\d\d)', f)#####   #####
                    if len(dot181) == 0:
                        dot181 = re.findall('f(\d)', f)#######   #######
                        m181h = float(dot181[0])
                        sheet.update_cell(r, day, m181h)
                        dot191 = re.findall('f\d(\d\.\d\d)', f)#######  ########
                        m191h = float(dot191[0])
                        d191 = day + 1
                        sheet.update_cell(r, d191, m191h)
                        if len(f) > 6:#################
                            T = f[6:]##################
                            for x in T:
                                tN = int(x) + 1
                                dayt = day + tN
                                sheet.update_cell(r, dayt, "YES")
                    else:
                        m181h = float(dot181[0])
                        sheet.update_cell(r, day, m181h)
                        dot191 = re.findall('f\d\.\d\d(\d)', f)#########    ##########
                        m191h = float(dot191[0])
                        d191 = day + 1
                        sheet.update_cell(r, d191, m191h)
                        if len(f) > 6:#######################
                            T = f[6:]########################
                            for x in T:
                                tN = int(x) + 1
                                dayt = day + tN
                                sheet.update_cell(r, dayt, "YES")
            else:
                dlist = list()
                for x in f:##########################
                    dlist.append(x)
                m181h = int(dlist[1])
                sheet.update_cell(r, day, m181h)
                m191h = int(dlist[2])
                d191 = day + 1
                sheet.update_cell(r, d191, m191h)
                if len(f) > 3:################
                    T = f[3:]##############
                    for x in T:
                        tN = int(x) + 1
                        dayt = day + tN
                        sheet.update_cell(r, dayt, "YES")
###########################################################################################
    if sa:##############
        day = 42############
        for x in sa:###############
            s = str(x)#####################
            dot = re.findall('(\d\.\d\d)', s)################
            if dot:
                if len(dot) == 2:
                    dot181 = re.findall('s(\d\.\d\d)', s)#############     ##############
                    m181h = float(dot181[0])
                    sheet.update_cell(r, day, m181h)
                    dot191 = re.findall('s\d\.\d\d(\d\.\d\d)', s)#########   ###########
                    m191h = float(dot191[0])
                    d191 = day+1
                    sheet.update_cell(r, d191, m191h)
                    if len(s) > 9:###############
                        T = f[9:] ##########
                        for x in T:
                            tN = int(x) + 1
                            dayt = day + tN
                            sheet.update_cell(r, dayt, "YES")
                else:
                    dot181 = re.findall('s(\d\.\d\d)', s)#####   #####
                    if len(dot181) == 0:
                        dot181 = re.findall('s(\d)', s)#######   #######
                        m181h = float(dot181[0])
                        sheet.update_cell(r, day, m181h)
                        dot191 = re.findall('s\d(\d\.\d\d)', s)#######  ########
                        m191h = float(dot191[0])
                        d191 = day + 1
                        sheet.update_cell(r, d191, m191h)
                        if len(s) > 6:#################
                            T = s[6:]##################
                            for x in T:
                                tN = int(x) + 1
                                dayt = day + tN
                                sheet.update_cell(r, dayt, "YES")
                    else:
                        m181h = float(dot181[0])
                        sheet.update_cell(r, day, m181h)
                        dot191 = re.findall('s\d\.\d\d(\d)', s)#########    ##########
                        m191h = float(dot191[0])
                        d191 = day + 1
                        sheet.update_cell(r, d191, m191h)
                        if len(s) > 6:#######################
                            T = s[6:]########################
                            for x in T:
                                tN = int(x) + 1
                                dayt = day + tN
                                sheet.update_cell(r, dayt, "YES")
            else:
                dlist = list()
                for x in s:##########################
                    dlist.append(x)
                m181h = int(dlist[1])
                sheet.update_cell(r, day, m181h)
                m191h = int(dlist[2])
                d191 = day + 1
                sheet.update_cell(r, d191, m191h)
                if len(s) > 3:################
                    T = s[3:]##############
                    for x in T:
                        tN = int(x) + 1
                        dayt = day + tN
                        sheet.update_cell(r, dayt, "YES")
###########################################################################################
    if su:##############
        day = 50############
        for x in su:###############
            u = str(x)#####################
            dot = re.findall('(\d\.\d\d)', u)################
            if dot:
                if len(dot) == 2:
                    dot181 = re.findall('u(\d\.\d\d)', u)#############     ##############
                    m181h = float(dot181[0])
                    sheet.update_cell(r, day, m181h)
                    dot191 = re.findall('u\d\.\d\d(\d\.\d\d)', u)#########   ###########
                    m191h = float(dot191[0])
                    d191 = day+1
                    sheet.update_cell(r, d191, m191h)
                    if len(u) > 9:###############
                        T = u[9:] ##########
                        for x in T:
                            tN = int(x) + 1
                            dayt = day + tN
                            sheet.update_cell(r, dayt, "YES")
                else:
                    dot181 = re.findall('u(\d\.\d\d)', u)#####   #####
                    if len(dot181) == 0:
                        dot181 = re.findall('u(\d)', u)#######   #######
                        m181h = float(dot181[0])
                        sheet.update_cell(r, day, m181h)
                        dot191 = re.findall('u\d(\d\.\d\d)', u)#######  ########
                        m191h = float(dot191[0])
                        d191 = day + 1
                        sheet.update_cell(r, d191, m191h)
                        if len(u) > 6:#################
                            T = u[6:]##################
                            for x in T:
                                tN = int(x) + 1
                                dayt = day + tN
                                sheet.update_cell(r, dayt, "YES")
                    else:
                        m181h = float(dot181[0])
                        sheet.update_cell(r, day, m181h)
                        dot191 = re.findall('u\d\.\d\d(\d)', u)#########    ##########
                        m191h = float(dot191[0])
                        d191 = day + 1
                        sheet.update_cell(r, d191, m191h)
                        if len(u) > 6:#######################
                            T = u[6:]########################
                            for x in T:
                                tN = int(x) + 1
                                dayt = day + tN
                                sheet.update_cell(r, dayt, "YES")
            else:
                dlist = list()
                for x in u:##########################
                    dlist.append(x)
                m181h = int(dlist[1])
                sheet.update_cell(r, day, m181h)
                m191h = int(dlist[2])
                d191 = day + 1
                sheet.update_cell(r, d191, m191h)
                if len(u) > 3:################
                    T = u[3:]##############
                    for x in T:
                        tN = int(x) + 1
                        dayt = day + tN
                        sheet.update_cell(r, dayt, "YES")
