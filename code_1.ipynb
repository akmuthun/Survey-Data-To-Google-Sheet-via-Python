# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials


from colorama import Fore, Back, Style

scope = ["https://spreadsheets.google.com/feeds",'https://www.googleapis.com/auth/spreadsheets',"https://www.googleapis.com/auth/drive.file","https://www.googleapis.com/auth/drive"]
#include json file which was provided from google
creds = ServiceAccountCredentials.from_json_keyfile_name("cred.json", scope)
#authorizing access
client = gspread.authorize(creds)
#specify the google sheet to read
sheet = client.open("Math Work log SECTION 1 Spring 2019").sheet1
# Get a list of all records
data = sheet.get_all_records()  # Get a list of all records
# Get the name column
ncol = sheet.col_values(1)  # Get a specific column

names =ncol[2:]
#input the raw number of the starting name
start = input("cell num?" )
n = int(start)-3
#start to loop with the selected name
cutnames = names[n:]
days = [2,10,18,26,34,42,50]
for name in cutnames:
    print(Fore.WHITE+"Enter data for: "+Fore.GREEN + name)
    r = names.index(name) + 3
    f= 10
    while f == 10:
        day = input(Fore.GREEN +"Enter a day: ")
        if day != "z":
            if day == "m":
                day = 2
                date = "Monday"
                m181h = float(input(Fore.RED + date + " MAT-181 hours?"))
                m191h = float(input(Fore.YELLOW + date + " MAT-191 hours?"))
                sheet.update_cell(r, day, m181h)
                day191 = day + 1
                sheet.update_cell(r, day191, m191h)
                T = input(Fore.BLUE + "Task numbers?")
                t = int(T)
                if t != 0:
                    for x in T:
                        tN = int(x) + 1
                        dayt = day + tN
                        sheet.update_cell(r, dayt, "YES")
                continue
            elif day == "t":
                day = 10
                date = "Tuesday"
                m181h = float(input(Fore.RED + date + " MAT-181 hours?"))
                m191h = float(input(Fore.YELLOW + date + " MAT-191 hours?"))
                sheet.update_cell(r, day, m181h)
                day191 = day + 1
                sheet.update_cell(r, day191, m191h)
                T = input(Fore.BLUE + "Task numbers?")
                t = int(T)
                if t != 0:
                    for x in T:
                        tN = int(x) + 1
                        dayt = day + tN
                        sheet.update_cell(r, dayt, "YES")
                continue
            elif day == "w":
                day = 18
                date = "Wednesday"
                m181h = float(input(Fore.RED + date + " MAT-181 hours?"))
                m191h = float(input(Fore.YELLOW + date + " MAT-191 hours?"))
                sheet.update_cell(r, day, m181h)
                day191 = day + 1
                sheet.update_cell(r, day191, m191h)
                T = input(Fore.BLUE + "Task numbers?")
                t = int(T)
                if t != 0:
                    for x in T:
                        tN = int(x) + 1
                        dayt = day + tN
                        sheet.update_cell(r, dayt, "YES")
                continue
            elif day == "h":
                day = 26
                date = "Thursday"
                m181h = float(input(Fore.RED + date + " MAT-181 hours?"))
                m191h = float(input(Fore.YELLOW + date + " MAT-191 hours?"))
                sheet.update_cell(r, day, m181h)
                day191 = day + 1
                sheet.update_cell(r, day191, m191h)
                T = input(Fore.BLUE + "Task numbers?")
                t = int(T)
                if t != 0:
                    for x in T:
                        tN = int(x) + 1
                        dayt = day + tN
                        sheet.update_cell(r, dayt, "YES")
                continue
            elif day == "f":
                day = 34
                date = "Friday"
                m181h = float(input(Fore.RED + date + " MAT-181 hours?"))
                m191h = float(input(Fore.YELLOW + date + " MAT-191 hours?"))
                sheet.update_cell(r, day, m181h)
                day191 = day + 1
                sheet.update_cell(r, day191, m191h)
                T = input(Fore.BLUE + "Task numbers?")
                t = int(T)
                if t != 0:
                    for x in T:
                        tN = int(x) + 1
                        dayt = day + tN
                        sheet.update_cell(r, dayt, "YES")
                continue
            elif day == "s":
                 day = 42
                 date = "Saturday"
                 m181h = float(input(Fore.RED + date + " MAT-181 hours?"))
                 m191h = float(input(Fore.YELLOW + date + " MAT-191 hours?"))
                 sheet.update_cell(r, day, m181h)
                 day191 = day + 1
                 sheet.update_cell(r, day191, m191h)
                 T = input(Fore.BLUE + "Task numbers?")
                 t = int(T)
                 if t != 0:
                    for x in T:
                        tN = int(x) + 1
                        dayt = day + tN
                        sheet.update_cell(r, dayt, "YES")
                 continue
            elif day == "u":
                day = 50
                date = "Sunday"
                m181h = float(input(Fore.RED + date + " MAT-181 hours?"))
                m191h = float(input(Fore.YELLOW + date + " MAT-191 hours?"))
                sheet.update_cell(r, day, m181h)
                day191 = day + 1
                sheet.update_cell(r, day191, m191h)
                T = input(Fore.BLUE + "Task numbers?")
                t = int(T)
                if t != 0:
                    for x in T:
                        tN = int(x) + 1
                        dayt = day + tN
                        sheet.update_cell(r, dayt, "YES")
        f=11
